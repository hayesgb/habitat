# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import train_classifier_pipeline
trained_classifier = train_classifier_pipeline.main()
trained_classifier.feature_importances_.shape
# Out:
# /Users/Greg/anaconda/envs/main/lib/python3.4/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/Greg/anaconda/envs/main/lib/python3.4/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# No errors were found in the cleaning of email addresses.
#           first appeal date  first gift date  first gift amount  \
# id
# ...

# %%
trained_classifier.feature_importances_
# Out:
# array([  1.23297644e-02,   1.19984179e-02,   1.58780428e-02,
#          7.42080903e-03,   5.95696528e-03,   1.26968795e-02,
#          2.68822404e-03,   4.45973951e-05,   1.82659929e-03,
#          2.81883618e-03,   6.83919099e-03,   1.30208884e-02,
#          1.33961542e-02,   1.62405221e-05,   1.84725082e-02,
#          1.00852139e-02,   6.71424392e-03,   1.48804707e-02,
#          4.58395687e-03,   9.80157166e-03,   6.09512577e-03,
#          7.26163076e-03,   9.18979164e-04,   1.68597090e-03,
#          1.93322704e-03,   7.43152626e-03,   1.87188017e-02,
#          8.32138605e-03,   2.11011100e-03,   5.63764991e-03,
#          4.03021614e-03,   2.10840479e-02,   3.80153698e-03,
#          1.10968578e-03,   1.60319388e-03,   1.33036665e-03,
#          6.66586981e-03,   1.54571672e-03,   2.69854571e-03,
#          3.68845157e-03,   1.13461764e-03,   1.04049027e-02,
#          7.36123914e-03,   3.21359495e-03,   7.30866882e-03,
# ...

# %%
importances = trained_classifier.feature_importances_
indices = np.argsort(importances)[::-1]
print('Feature ranking:')
for f in range(len(trained_classifier.feature_importances_)):
    print('{}. feature {} {}'.format((f+1), indices[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 118 0.24855805450013418
# 2. feature 117 0.16687909574498921
# 3. feature 119 0.06378496133785685
# 4. feature 31 0.02108404788769742
# 5. feature 26 0.01871880169880618
# 6. feature 14 0.018472508193951916
# 7. feature 2 0.015878042842119085
# 8. feature 17 0.014880470733909698
# 9. feature 86 0.014331398268404244
# 10. feature 12 0.013396154197845822
# 11. feature 11 0.01302088841983256
# 12. feature 5 0.012696879509584461
# 13. feature 0 0.012329764407234987
# 14. feature 1 0.011998417897762839
# 15. feature 41 0.010404902680119187
# 16. feature 15 0.010085213920399683
# 17. feature 19 0.009801571664476042
# 18. feature 112 0.00961249840030558
# 19. feature 115 0.009251100273275421
# 20. feature 27 0.008321386050340702
# 21. feature 25 0.007431526263196128
# 22. feature 3 0.007420809030139563
# 23. feature 42 0.007361239144630494
# 24. feature 44 0.007308668815017162
# 25. feature 21 0.007261630762688575
# 26. feature 101 0.006900040881295583
# ...
